# %% [markdown]
# ### Agent With Memory

# %%
import os 
from langchain.chat_models import init_chat_model
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
model =init_chat_model("groq:llama-3.1-8b-instant")
model
# Out:
# ChatGroq(output_version=None, profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x7abe9a9a7ef0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x7abe9add39e0>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

# %%
agent=create_agent(
    model="groq:llama-3.1-8b-instant",
    checkpointer=InMemorySaver()
)

# %%
### Run with thread id 
config={"configurable":{"thread_id":"test1"}}

# %%
from langchain_core.messages import HumanMessage, SystemMessage
response=agent.invoke({"messages":[HumanMessage(content="Hii my name is Girish!")]},config=config)
response
# Out:
# {'messages': [HumanMessage(content='Hii my name is Girish!', additional_kwargs={}, response_metadata={}, id='fb2fef6d-f920-4e41-a0ec-405604b7826f'),
#   AIMessage(content='Hello Girish, nice to meet you. Is there something I can help you with or would you like to chat?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 43, 'total_tokens': 68, 'completion_time': 0.030680841, 'completion_tokens_details': None, 'prompt_time': 0.005524949, 'prompt_tokens_details': None, 'queue_time': 0.087446541, 'total_time': 0.03620579}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ec5f6-a0b0-73b2-82e7-8da885a320fc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 25, 'total_tokens': 68})]}

# %%
agent.invoke({"messages":[HumanMessage(content="Hii what is my name!")]},config=config)
# Out:
# {'messages': [HumanMessage(content='Hii my name is Girish!', additional_kwargs={}, response_metadata={}, id='fb2fef6d-f920-4e41-a0ec-405604b7826f'),
#   AIMessage(content='Hello Girish, nice to meet you. Is there something I can help you with or would you like to chat?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 43, 'total_tokens': 68, 'completion_time': 0.030680841, 'completion_tokens_details': None, 'prompt_time': 0.005524949, 'prompt_tokens_details': None, 'queue_time': 0.087446541, 'total_time': 0.03620579}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ec5f6-a0b0-73b2-82e7-8da885a320fc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 25, 'total_tokens': 68}),
# ...

# %%
### Run with thread id 2
config1={"configurable":{"thread_id":"test2"}}
from langchain_core.messages import HumanMessage, SystemMessage
response=agent.invoke({"messages":[HumanMessage(content="Hii my name is Alice!")]},config=config1)
print(agent.invoke({"messages":[HumanMessage(content="Hii what is my name!")]},config=config1))
# Out:
# {'messages': [HumanMessage(content='Hii my name is Alice!', additional_kwargs={}, response_metadata={}, id='0e6cf743-06fc-4440-9f6a-734b1da3fb42'), AIMessage(content="Nice to meet you, Alice. How's your day going so far?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 42, 'total_tokens': 58, 'completion_time': 0.021933753, 'completion_tokens_details': None, 'prompt_time': 0.002360039, 'prompt_tokens_details': None, 'queue_time': 0.158492401, 'total_time': 0.024293792}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_7ccc667439', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ec5f9-51d0-7670-8363-d4c21958721a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 16, 'total_tokens': 58}), HumanMessage(content='Hii what is my name!', additional_kwargs={}, response_metadata={}, id='b0e47be7-3cbb-4a61-948f-c09c1b0b
# ...

# %%
agent.invoke({"messages":[HumanMessage(content="Hii what is my name!")]},config=config1)
# Out:
# {'messages': [HumanMessage(content='Hii my name is Alice!', additional_kwargs={}, response_metadata={}, id='0e6cf743-06fc-4440-9f6a-734b1da3fb42'),
#   AIMessage(content="Nice to meet you, Alice. How's your day going so far?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 42, 'total_tokens': 58, 'completion_time': 0.021933753, 'completion_tokens_details': None, 'prompt_time': 0.002360039, 'prompt_tokens_details': None, 'queue_time': 0.158492401, 'total_time': 0.024293792}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_7ccc667439', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ec5f9-51d0-7670-8363-d4c21958721a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 16, 'total_tokens': 58}),
# ...
